# %%
from bs4 import BeautifulSoup
import operator
import time
from selenium import webdriver
import os
from collections import defaultdict, Counter
import pandas as pd
import numpy as np

from src.styling import *
from src.utils import *
from src.categories import *
from src.points import *

# %%
def get_stats(leagues, n_weeks):
    last_week_scores = []
    all_weeks_scores = []
    browser = webdriver.Chrome()
    for league in leagues:
        
        espn_scoreboard_url = 'https://fantasy.espn.com/hockey/league/scoreboard'
        urls = [f"{espn_scoreboard_url}?leagueId={league}&matchupPeriodId={i+1}" for i in range(n_weeks)]

        result_lk = defaultdict(list)
        opponent_lk = defaultdict(list)
        result_places = defaultdict(list)
        opponent_places = defaultdict(list)
        for index, url in enumerate(urls):
            browser.get(url)
            time.sleep(8)
            content = browser.page_source
            data = BeautifulSoup(content)
            results = get_week_stats(data)
            
            opp_dict = {}
            for sc in results:
                opp_dict[sc[0][0]] = sc[1][0]
                opp_dict[sc[1][0]] = sc[0][0]
            
            scores = get_sorted_week_scores(results)
            
            league_name = get_league_name(data)
            for score in scores:
                all_weeks_scores.append((score[0], score[1], index+1, league_name))
                if index == n_weeks - 1:
                    last_week_scores.append((score[0], score[1], league_name))
                    
            places = get_places(scores)

            lk = get_luck_score(results, places)
            for item in lk:
                result_places[item].append(places[item] if places[item] % 1.0 != 0 else int(places[item]))
                result_lk[item].append(lk[item] if lk[item] % 1.0 > 1e-7 else int(lk[item]))
            
            for team in opp_dict:
                opp_place = places[opp_dict[team]]
                opponent_places[team].append(opp_place if opp_place % 1.0 != 0 else int(opp_place))
                opp_lk = lk[opp_dict[team]]
                opponent_lk[team].append(opp_lk if opp_lk % 1.0 != 0 else int(opp_lk))

        for key in result_lk:
            result_lk[key].append(np.sum(result_lk[key]))
        for key in result_places:
            result_places[key].append(np.sum(result_places[key]))
        for key in opponent_lk:
            opponent_lk[key].append(np.sum(opponent_lk[key]))
        for key in opponent_places:
            opponent_places[key].append(np.sum(opponent_places[key]))
    
        weeks = [f'Week {i+1}' for i in range(n_weeks)]
        styles = [dict(selector='caption', props=[('text-align', 'center')])]
        
        df_lk = pd.DataFrame(data=list(result_lk.values()),
                          index=result_lk.keys(), 
                          columns=weeks + ['SUM'])
        df_lk = df_lk.sort_values(['SUM'])
        display(df_lk.style.set_table_styles(styles).\
                applymap(color_value, subset=weeks).\
                set_caption(f'{league_name}: luck scores'))
        
        df_places = pd.DataFrame(data=list(result_places.values()),
                          index=result_places.keys(), 
                          columns=weeks + ['SUM'])
        df_places = df_places.sort_values(['SUM'])
        styles = [dict(selector='caption', props=[('text-align', 'center')])]
        display(df_places.style.set_table_styles(styles).\
                apply(color_place_column, subset=weeks).\
                set_caption(f'{league_name}: places'))                    
        
        df_opp_lk = pd.DataFrame(data=list(opponent_lk.values()),
                                 index=opponent_lk.keys(), 
                                 columns=weeks + ['SUM'])
        df_opp_lk = df_opp_lk.sort_values(['SUM'])
        display(df_opp_lk.style.set_table_styles(styles).\
                applymap(color_opponent_value, subset=weeks).\
                set_caption(f'{league_name}: opponent luck scores'))
        
        df_opp_places = pd.DataFrame(data=list(opponent_places.values()),
                          index=opponent_places.keys(), 
                          columns=weeks + ['SUM'])
        df_opp_places = df_opp_places.sort_values(['SUM'])
        styles = [dict(selector='caption', props=[('text-align', 'center')])]
        display(df_opp_places.style.set_table_styles(styles).\
                apply(color_opponent_place_column, subset=weeks).\
                set_caption(f'{league_name}: opponent places'))
                                         
    return df_lk, df_places, last_week_scores, all_weeks_scores

# %%
leagues = [8290, 31769, 33730, 52338, 57256, 73362809]
a, b, c, d = get_stats(leagues, 12)

# %%
week_scores_sorted = sorted(c, key=operator.itemgetter(1), reverse=True)

n_top = int(len(week_scores_sorted) / len(leagues))
data = pd.DataFrame(data = week_scores_sorted[:n_top], 
                    index=np.arange(1, 1 + n_top),
                    columns=['Team', 'Score', 'League'])
data

# %%
all_scores_soted = sorted(d, key=operator.itemgetter(1), reverse=True)

data = pd.DataFrame(data = all_scores_soted[:20], 
                    index=np.arange(1, 1 + 20),
                    columns=['Team', 'Score', 'Week' ,'League'])
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f944a5494115> in <module>
# ----> 1 all_scores_soted = sorted(d, key=operator.itemgetter(1), reverse=True)
#       2
#       3 data = pd.DataFrame(data = all_scores_soted[:20],
#       4                     index=np.arange(1, 1 + 20),
#       5                     columns=['Team', 'Score', 'Week' ,'League'])
#
# NameError: name 'd' is not defined

# %%
leagues = [27465869]
a, b, c, d = get_stats(leagues, 2)
# Out:
# <style  type="text/css" >
#     #T_44bc4a7a_2194_11ea_8761_f218983e2b56 caption {
#           text-align: center;
#     }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row0_col0 {
#             color:  red;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row0_col1 {
#             color:  black;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row1_col0 {
#             color:  green;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row1_col1 {
#             color:  red;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row2_col0 {
#             color:  black;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row2_col1 {
#             color:  black;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row3_col0 {
#             color:  black;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row3_col1 {
#             color:  black;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row4_col0 {
#             color:  black;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row4_col1 {
#             color:  black;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row5_col0 {
#             color:  black;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row5_col1 {
#             color:  black;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row6_col0 {
#             color:  black;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row6_col1 {
#             color:  black;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row7_col0 {
#             color:  black;
#         }    #T_44bc4a7a_2194_11ea_8761_f218983e2b56row7_col1 {
#             color:  green;
#         }</style>
# <table id="T_44bc4a7a_2194_11ea_8761_f218983e2b56" ><caption>My 2020 League: luck scores</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Week 1</th>
#         <th class="col_heading level0 col1" >Week 2</th>
#         <th class="col_heading level0 col2" >SUM</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_44bc4a7a_2194_11ea_8761_f218983e2b56level0_row0" class="row_heading level0 row0" >Team Chepikau</th>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row0_col0" class="data row0 col0" >-3</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row0_col1" class="data row0 col1" >0</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row0_col2" class="data row0 col2" >-3</td>
#     </tr>    <tr>
#         <th id="T_44bc4a7a_2194_11ea_8761_f218983e2b56level0_row1" class="row_heading level0 row1" >Team Crosby</th>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row1_col0" class="data row1 col0" >1</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row1_col1" class="data row1 col1" >-2</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row1_col2" class="data row1 col2" >-1</td>
#     </tr>    <tr>
#         <th id="T_44bc4a7a_2194_11ea_8761_f218983e2b56level0_row2" class="row_heading level0 row2" >Brest  Blue Arrows </th>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row2_col0" class="data row2 col0" >0</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row2_col1" class="data row2 col1" >0</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row2_col2" class="data row2 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_44bc4a7a_2194_11ea_8761_f218983e2b56level0_row3" class="row_heading level0 row3" >Fantasy God</th>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row3_col0" class="data row3 col0" >0</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row3_col1" class="data row3 col1" >0</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row3_col2" class="data row3 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_44bc4a7a_2194_11ea_8761_f218983e2b56level0_row4" class="row_heading level0 row4" >Avangar Omsk</th>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row4_col0" class="data row4 col0" >0</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row4_col1" class="data row4 col1" >0</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row4_col2" class="data row4 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_44bc4a7a_2194_11ea_8761_f218983e2b56level0_row5" class="row_heading level0 row5" >Fort Boyaras</th>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row5_col0" class="data row5 col0" >0</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row5_col1" class="data row5 col1" >0</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row5_col2" class="data row5 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_44bc4a7a_2194_11ea_8761_f218983e2b56level0_row6" class="row_heading level0 row6" >Team Paliavy</th>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row6_col0" class="data row6 col0" >0</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row6_col1" class="data row6 col1" >0</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row6_col2" class="data row6 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_44bc4a7a_2194_11ea_8761_f218983e2b56level0_row7" class="row_heading level0 row7" >St. Petersburg Bastards</th>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row7_col0" class="data row7 col0" >0</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row7_col1" class="data row7 col1" >1</td>
#         <td id="T_44bc4a7a_2194_11ea_8761_f218983e2b56row7_col2" class="data row7 col2" >1</td>
#     </tr></tbody>
# </table>
# <style  type="text/css" >
#     #T_44c0168c_2194_11ea_b566_f218983e2b56 caption {
#           text-align: center;
#     }    #T_44c0168c_2194_11ea_b566_f218983e2b56row0_col0 {
#             color:  blue;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row0_col1 {
#             color:  blue;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row1_col0 {
#             color:  blue;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row1_col1 {
#             color:  red;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row2_col0 {
#             color:  red;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row2_col1 {
#             color:  blue;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row3_col0 {
#             color:  red;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row3_col1 {
#             color:  blue;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row4_col0 {
#             color:  red;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row4_col1 {
#             color:  red;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row5_col0 {
#             color:  red;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row5_col1 {
#             color:  red;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row6_col0 {
#             color:  blue;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row6_col1 {
#             color:  red;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row7_col0 {
#             color:  red;
#         }    #T_44c0168c_2194_11ea_b566_f218983e2b56row7_col1 {
#             color:  red;
#         }</style>
# <table id="T_44c0168c_2194_11ea_b566_f218983e2b56" ><caption>My 2020 League: places</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Week 1</th>
#         <th class="col_heading level0 col1" >Week 2</th>
#         <th class="col_heading level0 col2" >SUM</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_44c0168c_2194_11ea_b566_f218983e2b56level0_row0" class="row_heading level0 row0" >Fort Boyaras</th>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row0_col0" class="data row0 col0" >3</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row0_col1" class="data row0 col1" >2</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row0_col2" class="data row0 col2" >5</td>
#     </tr>    <tr>
#         <th id="T_44c0168c_2194_11ea_b566_f218983e2b56level0_row1" class="row_heading level0 row1" >St. Petersburg Bastards</th>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row1_col0" class="data row1 col0" >1</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row1_col1" class="data row1 col1" >5</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row1_col2" class="data row1 col2" >6</td>
#     </tr>    <tr>
#         <th id="T_44c0168c_2194_11ea_b566_f218983e2b56level0_row2" class="row_heading level0 row2" >Team Crosby</th>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row2_col0" class="data row2 col0" >5</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row2_col1" class="data row2 col1" >3</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row2_col2" class="data row2 col2" >8</td>
#     </tr>    <tr>
#         <th id="T_44c0168c_2194_11ea_b566_f218983e2b56level0_row3" class="row_heading level0 row3" >Avangar Omsk</th>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row3_col0" class="data row3 col0" >7</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row3_col1" class="data row3 col1" >1</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row3_col2" class="data row3 col2" >8</td>
#     </tr>    <tr>
#         <th id="T_44c0168c_2194_11ea_b566_f218983e2b56level0_row4" class="row_heading level0 row4" >Brest  Blue Arrows </th>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row4_col0" class="data row4 col0" >6</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row4_col1" class="data row4 col1" >4</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row4_col2" class="data row4 col2" >10</td>
#     </tr>    <tr>
#         <th id="T_44c0168c_2194_11ea_b566_f218983e2b56level0_row5" class="row_heading level0 row5" >Fantasy God</th>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row5_col0" class="data row5 col0" >4</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row5_col1" class="data row5 col1" >6</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row5_col2" class="data row5 col2" >10</td>
#     </tr>    <tr>
#         <th id="T_44c0168c_2194_11ea_b566_f218983e2b56level0_row6" class="row_heading level0 row6" >Team Chepikau</th>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row6_col0" class="data row6 col0" >2</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row6_col1" class="data row6 col1" >8</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row6_col2" class="data row6 col2" >10</td>
#     </tr>    <tr>
#         <th id="T_44c0168c_2194_11ea_b566_f218983e2b56level0_row7" class="row_heading level0 row7" >Team Paliavy</th>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row7_col0" class="data row7 col0" >8</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row7_col1" class="data row7 col1" >7</td>
#         <td id="T_44c0168c_2194_11ea_b566_f218983e2b56row7_col2" class="data row7 col2" >15</td>
#     </tr></tbody>
# </table>
# <style  type="text/css" >
#     #T_44c295c6_2194_11ea_9568_f218983e2b56 caption {
#           text-align: center;
#     }    #T_44c295c6_2194_11ea_9568_f218983e2b56row0_col0 {
#             color:  green;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row0_col1 {
#             color:  black;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row1_col0 {
#             color:  black;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row1_col1 {
#             color:  green;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row2_col0 {
#             color:  black;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row2_col1 {
#             color:  black;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row3_col0 {
#             color:  black;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row3_col1 {
#             color:  black;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row4_col0 {
#             color:  black;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row4_col1 {
#             color:  black;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row5_col0 {
#             color:  black;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row5_col1 {
#             color:  black;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row6_col0 {
#             color:  black;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row6_col1 {
#             color:  red;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row7_col0 {
#             color:  red;
#         }    #T_44c295c6_2194_11ea_9568_f218983e2b56row7_col1 {
#             color:  black;
#         }</style>
# <table id="T_44c295c6_2194_11ea_9568_f218983e2b56" ><caption>My 2020 League: opponent luck scores</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Week 1</th>
#         <th class="col_heading level0 col1" >Week 2</th>
#         <th class="col_heading level0 col2" >SUM</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_44c295c6_2194_11ea_9568_f218983e2b56level0_row0" class="row_heading level0 row0" >St. Petersburg Bastards</th>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row0_col0" class="data row0 col0" >-3</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row0_col1" class="data row0 col1" >0</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row0_col2" class="data row0 col2" >-3</td>
#     </tr>    <tr>
#         <th id="T_44c295c6_2194_11ea_9568_f218983e2b56level0_row1" class="row_heading level0 row1" >Fort Boyaras</th>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row1_col0" class="data row1 col0" >0</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row1_col1" class="data row1 col1" >-2</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row1_col2" class="data row1 col2" >-2</td>
#     </tr>    <tr>
#         <th id="T_44c295c6_2194_11ea_9568_f218983e2b56level0_row2" class="row_heading level0 row2" >Brest  Blue Arrows </th>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row2_col0" class="data row2 col0" >0</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row2_col1" class="data row2 col1" >0</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row2_col2" class="data row2 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_44c295c6_2194_11ea_9568_f218983e2b56level0_row3" class="row_heading level0 row3" >Team Chepikau</th>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row3_col0" class="data row3 col0" >0</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row3_col1" class="data row3 col1" >0</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row3_col2" class="data row3 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_44c295c6_2194_11ea_9568_f218983e2b56level0_row4" class="row_heading level0 row4" >Team Crosby</th>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row4_col0" class="data row4 col0" >0</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row4_col1" class="data row4 col1" >0</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row4_col2" class="data row4 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_44c295c6_2194_11ea_9568_f218983e2b56level0_row5" class="row_heading level0 row5" >Team Paliavy</th>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row5_col0" class="data row5 col0" >0</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row5_col1" class="data row5 col1" >0</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row5_col2" class="data row5 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_44c295c6_2194_11ea_9568_f218983e2b56level0_row6" class="row_heading level0 row6" >Fantasy God</th>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row6_col0" class="data row6 col0" >0</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row6_col1" class="data row6 col1" >1</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row6_col2" class="data row6 col2" >1</td>
#     </tr>    <tr>
#         <th id="T_44c295c6_2194_11ea_9568_f218983e2b56level0_row7" class="row_heading level0 row7" >Avangar Omsk</th>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row7_col0" class="data row7 col0" >1</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row7_col1" class="data row7 col1" >0</td>
#         <td id="T_44c295c6_2194_11ea_9568_f218983e2b56row7_col2" class="data row7 col2" >1</td>
#     </tr></tbody>
# </table>
# <style  type="text/css" >
#     #T_44c584f4_2194_11ea_8750_f218983e2b56 caption {
#           text-align: center;
#     }    #T_44c584f4_2194_11ea_8750_f218983e2b56row0_col0 {
#             color:  red;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row0_col1 {
#             color:  red;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row1_col0 {
#             color:  red;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row1_col1 {
#             color:  blue;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row2_col0 {
#             color:  red;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row2_col1 {
#             color:  blue;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row3_col0 {
#             color:  blue;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row3_col1 {
#             color:  red;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row4_col0 {
#             color:  blue;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row4_col1 {
#             color:  blue;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row5_col0 {
#             color:  blue;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row5_col1 {
#             color:  red;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row6_col0 {
#             color:  blue;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row6_col1 {
#             color:  blue;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row7_col0 {
#             color:  blue;
#         }    #T_44c584f4_2194_11ea_8750_f218983e2b56row7_col1 {
#             color:  blue;
#         }</style>
# <table id="T_44c584f4_2194_11ea_8750_f218983e2b56" ><caption>My 2020 League: opponent places</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Week 1</th>
#         <th class="col_heading level0 col1" >Week 2</th>
#         <th class="col_heading level0 col2" >SUM</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_44c584f4_2194_11ea_8750_f218983e2b56level0_row0" class="row_heading level0 row0" >Team Paliavy</th>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row0_col0" class="data row0 col0" >3</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row0_col1" class="data row0 col1" >1</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row0_col2" class="data row0 col2" >4</td>
#     </tr>    <tr>
#         <th id="T_44c584f4_2194_11ea_8750_f218983e2b56level0_row1" class="row_heading level0 row1" >Team Chepikau</th>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row1_col0" class="data row1 col0" >1</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row1_col1" class="data row1 col1" >4</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row1_col2" class="data row1 col2" >5</td>
#     </tr>    <tr>
#         <th id="T_44c584f4_2194_11ea_8750_f218983e2b56level0_row2" class="row_heading level0 row2" >St. Petersburg Bastards</th>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row2_col0" class="data row2 col0" >2</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row2_col1" class="data row2 col1" >6</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row2_col2" class="data row2 col2" >8</td>
#     </tr>    <tr>
#         <th id="T_44c584f4_2194_11ea_8750_f218983e2b56level0_row3" class="row_heading level0 row3" >Team Crosby</th>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row3_col0" class="data row3 col0" >7</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row3_col1" class="data row3 col1" >2</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row3_col2" class="data row3 col2" >9</td>
#     </tr>    <tr>
#         <th id="T_44c584f4_2194_11ea_8750_f218983e2b56level0_row4" class="row_heading level0 row4" >Fantasy God</th>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row4_col0" class="data row4 col0" >6</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row4_col1" class="data row4 col1" >5</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row4_col2" class="data row4 col2" >11</td>
#     </tr>    <tr>
#         <th id="T_44c584f4_2194_11ea_8750_f218983e2b56level0_row5" class="row_heading level0 row5" >Fort Boyaras</th>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row5_col0" class="data row5 col0" >8</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row5_col1" class="data row5 col1" >3</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row5_col2" class="data row5 col2" >11</td>
#     </tr>    <tr>
#         <th id="T_44c584f4_2194_11ea_8750_f218983e2b56level0_row6" class="row_heading level0 row6" >Brest  Blue Arrows </th>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row6_col0" class="data row6 col0" >4</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row6_col1" class="data row6 col1" >8</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row6_col2" class="data row6 col2" >12</td>
#     </tr>    <tr>
#         <th id="T_44c584f4_2194_11ea_8750_f218983e2b56level0_row7" class="row_heading level0 row7" >Avangar Omsk</th>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row7_col0" class="data row7 col0" >5</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row7_col1" class="data row7 col1" >7</td>
#         <td id="T_44c584f4_2194_11ea_8750_f218983e2b56row7_col2" class="data row7 col2" >12</td>
#     </tr></tbody>
# </table>

# %%
week_scores_sorted = sorted(c, key=operator.itemgetter(1), reverse=True)

n_top = int(len(week_scores_sorted) / len(leagues))
data = pd.DataFrame(data = week_scores_sorted[:n_top], 
                    index=np.arange(1, 1 + n_top),
                    columns=['Team', 'Score', 'League'])
data
# Out:
#                       Team   Score          League
# 1             Avangar Omsk  1645.5  My 2020 League
# 2             Fort Boyaras  1532.5  My 2020 League
# 3              Team Crosby  1518.0  My 2020 League
# 4      Brest  Blue Arrows   1495.0  My 2020 League
# 5  St. Petersburg Bastards  1462.5  My 2020 League
# 6              Fantasy God  1347.5  My 2020 League
# 7             Team Paliavy  1204.5  My 2020 League
# 8            Team Chepikau  1112.0  My 2020 League

# %%
all_scores_soted = sorted(d, key=operator.itemgetter(1), reverse=True)

data = pd.DataFrame(data = all_scores_soted[:20], 
                    index=np.arange(1, 1 + 20),
                    columns=['Team', 'Score', 'Week' ,'League'])
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.6.6/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4872         blocks = form_blocks(arrays, names, axes)
# -> 4873         mgr = BlockManager(blocks, axes)
#    4874         mgr._consolidate_inplace()
#
# ~/.pyenv/versions/3.6.6/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, blocks, axes, do_integrity_check)
#    3281         if do_integrity_check:
# -> 3282             self._verify_integrity()
#    3283
#
# ~/.pyenv/versions/3.6.6/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in _verify_integrity(self)
#    3492             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# -> 3493                 construction_error(tot_items, block.shape[1:], self.axes)
#    3494         if len(self.items) != tot_items:
#
# ~/.pyenv/versions/3.6.6/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    4842     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4843         passed, implied))
#    4844
#
# ValueError: Shape of passed values is (4, 16), indices imply (4, 20)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-f944a5494115> in <module>
#       3 data = pd.DataFrame(data = all_scores_soted[:20],
#       4                     index=np.arange(1, 1 + 20),
# ----> 5                     columns=['Team', 'Score', 'Week' ,'League'])
#       6 data
#
# ~/.pyenv/versions/3.6.6/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     398
#     399                     mgr = _arrays_to_mgr(arrays, columns, index, columns,
# --> 400                                          dtype=dtype)
#     401                 else:
#     402                     mgr = self._init_ndarray(data, index, columns, dtype=dtype,
#
# ~/.pyenv/versions/3.6.6/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7362     axes = [_ensure_index(columns), _ensure_index(index)]
#    7363
# -> 7364     return create_block_manager_from_arrays(arrays, arr_names, axes)
#    7365
#    7366
#
# ~/.pyenv/versions/3.6.6/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4875         return mgr
#    4876     except ValueError as e:
# -> 4877         construction_error(len(arrays), arrays[0].shape, axes, e)
#    4878
#    4879
#
# ~/.pyenv/versions/3.6.6/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    4841         raise ValueError("Empty data passed with indices specified.")
#    4842     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4843         passed, implied))
#    4844
#    4845
#
# ValueError: Shape of passed values is (4, 16), indices imply (4, 20)

# %%
def get_scores_info(results, categories):
    indexes = []
    data = []
    
    for matchup in results:
        for player, score in matchup:
            indexes.append(player)
            data.append([cat_score if cat_score % 1.0 > 1e-7 else int(cat_score) for cat, cat_score in score])
    return {indexes[i]: data[i] for i in range(len(indexes))}


def get_expected_category_stat(score_pairs, category):
    scores = np.array([score for team, score in score_pairs])
    result = {}
    for team, sc in score_pairs:
        win_count = np.sum(scores < sc)
        draw_count = np.sum(scores == sc) - 1
        lost_count = np.sum(scores > sc)
        if category == 'TO':
            result[team] = np.array([lost_count, win_count, draw_count]) / (len(scores) - 1)
        else:
            result[team] = np.array([win_count, lost_count, draw_count]) / (len(scores) - 1)
    return result


def compare_scores(sc1, sc2):
    return list(sc1[[0,2,1]]) > list(sc2[[0,2,1]])

def get_expected_score_and_result(results):
    res = {}
    indexes = []
    data = []
    for matchup in results:
        for player, score in matchup:
            indexes.append(player)
            res[player] = np.array([0.0, 0.0, 0.0])
            data.append([cat_score for cat, cat_score in score])
    opponents_dict = {}        
    for matchup in results:
        opponents_dict[matchup[0][0]] = matchup[1][0]
        opponents_dict[matchup[1][0]] = matchup[0][0]
    data = np.array(data)
    for i in range(len(data[0])):
        pairs = [(team, score) for team, score in zip(indexes, data[:, i])]
        category = results[0][0][1][i][0]
        expected_stats = get_expected_category_stat(pairs, category)
        for player in expected_stats:
            concatted = np.vstack((expected_stats[player], res[player]))
            res[player] = concatted.sum(axis = 0)
    matchup_results = {}
    for team in opponents_dict:
        if compare_scores(res[team], res[opponents_dict[team]]):
            matchup_results[team] = 'W'
        elif compare_scores(res[opponents_dict[team]], res[team]):
            matchup_results[team] = 'L'
        else:
            matchup_results[team] = 'D'
    exp_categories = {}
    for player in res:
        res_rounded = map(lambda x: np.round(x, 1), res[player])
        res_formatted = map(lambda x: str(x) if x % 1.0 > 1e-7 else str(int(x)), res_rounded)
        exp_categories[player] = '-'.join(res_formatted)
        
    return exp_categories, matchup_results
        

def get_places_table(vvv, categories):
    places_table_data = defaultdict(list)
    for col in list(vvv.columns):
        pairs = [(index, vvv[col][index]) for index in vvv[col].index]
        pairs_sorted = sorted(pairs, key=operator.itemgetter(1), reverse=True if col != 'TO' else False)
        places = get_places(pairs_sorted)
        for index in places:
            places_table_data[index].append(places[index])
    for key in places_table_data:
        places_table_data[key].append(np.sum(places_table_data[key]))

    additional_table = pd.DataFrame(data=np.array(list(places_table_data.values())), 
                                    index=places_table_data.keys(), 
                                    columns=[f'{col} ' for col in categories] + ['SUM'])
    return additional_table


def get_best_and_worst_rows(addded, categories):
    best = {}
    worst = {}
    for col in categories:
        if col == 'TO':
            best[col] = addded[col].min()
            worst[col] = addded[col].max()
            best[f'{col} '] = ''
            worst[f'{col} '] = ''
        elif col in ['Score', 'ExpScore']:
            scores_for_sort = []
            for sc in addded[col]:
                sc_values = list(map(float, sc.split('-')))
                scores_for_sort.append([sc_values[0], sc_values[2], sc_values[1]])
                max_val = max(scores_for_sort)
                best[col] = '-'.join(map(str, map(lambda x: x if x % 1.0 > 1e-7 else int(x), [max_val[0], max_val[2], max_val[1]])))
                min_val = min(scores_for_sort)
                worst[col] = '-'.join(map(str, map(lambda x: x if x % 1.0 > 1e-7 else int(x), [min_val[0], min_val[2], min_val[1]])))
        else:
            best[col] = addded[col].max()
            worst[col] = addded[col].min()
            if col not in ['TP', 'ER']:
                best[f'{col} '] = ''
                worst[f'{col} '] = ''
    best['SUM'] = ''
    worst['SUM'] = ''
    if 'ER' in categories:
        best['ER'] = ''
        worst['ER'] = ''
    return best, worst

# %%
def get_best_and_worst_rows_for_scores(table):
    best = {}
    worst = {}
    for col in table.columns:
        if col not in ['WD', 'LD', 'DD', 'W', 'D', 'L']:
            scores_for_sort = []
            for sc in table[col]:
                sc_values = list(map(float, sc.split('-')))
                scores_for_sort.append([sc_values[0], sc_values[2], sc_values[1]])
            max_val = max(scores_for_sort)
            best[col] = '-'.join(map(str, map(lambda x: x if x % 1.0 > 1e-7 else int(x), [max_val[0], max_val[2], max_val[1]])))
            min_val = min(scores_for_sort)
            worst[col] = '-'.join(map(str, map(lambda x: x if x % 1.0 > 1e-7 else int(x), [min_val[0], min_val[2], min_val[1]])))
        else:
            best[col] = ''
            worst[col] = ''
    return best, worst


def get_diff(expected, real):
    e = list(map(float, expected.split('-')))
    r = list(map(float, real.split('-')))
    return list(map(lambda x: np.round(x, 1), [e[0] - r[0], e[1] - r[1], e[2] - r[2]]))


def calc_team_win_stat(team_stat_list):
    team_res_np = np.array(team_stat_list)
    n_win = int(np.sum(team_res_np == 'W'))
    n_lose = int(np.sum(team_res_np == 'L'))
    n_draw = int(np.sum(team_res_np == 'D'))
    return '-'.join(map(str, [n_win, n_lose, n_draw]))


def get_matchup_result(team_stat, opp_stat, categories):
    win_sc = 0
    lose_sc = 0
    draw_sc = 0
    for index, cat in enumerate(categories):
        if team_stat[index] == opp_stat[index]:
            draw_sc += 1
        elif team_stat[index] > opp_stat[index]:
            if cat == 'TO':
                lose_sc += 1
            else:
                win_sc += 1
        else:
            if cat == 'TO':
                win_sc += 1
            else:
                lose_sc += 1
    if win_sc > lose_sc:
        return 'W'
    elif win_sc == lose_sc:
        return 'D'
    else:
        return 'L'

# %%
week = 9
leagues = [43767928, 134112, 99121987, 282844, 199973, 142634, 174837]
cat_subset = [43767928, 134112]
# leagues = [43767928]
browser = webdriver.Chrome()
for league in leagues:
    link = f'https://fantasy.espn.com/basketball/league/scoreboard?leagueId={league}&matchupPeriodId={week}'
    browser.get(link)
    time.sleep(10)
    scoreboard_html_source = BeautifulSoup(browser.page_source)
    league_name = get_league_name(scoreboard_html_source)
    
    res, cat = get_week_results(scoreboard_html_source)
    scores_info = get_scores_info(res, cat)
    
    matchups_win_stats = {}
    for team in scores_info:
        week_wins = Counter()
        for opp in scores_info:
            if opp == team:
                continue
            fake_matchup_res = get_matchup_result(scores_info[team], scores_info[opp], cat)
            week_wins[fake_matchup_res] += 1
        tr = np.round((week_wins['W'] + week_wins['D'] * 0.5) / (len(scores_info) - 1), 2)
        matchups_win_stats[team] = tr if tr % 1.0 > 1e-7 else int(tr)
        
    vvv = pd.DataFrame(data=list(scores_info.values()), columns=cat, index=scores_info.keys())
    
    scores = get_week_stats(scoreboard_html_source, 'NBA')
    scores_dict = {}
    for sc in scores:
        scores_dict.update(sc)
        
    score_df = pd.DataFrame(data=list(scores_dict.values()), 
                            index=scores_dict.keys(), 
                            columns=['Score'])
    
    exp_score, exp_result = get_expected_score_and_result(res)
    exp_score_df =  pd.DataFrame(index=exp_score.keys(), columns=['ExpScore'], 
                                 data=list(exp_score.values()))
    matchups_df = pd.DataFrame(index=matchups_win_stats.keys(), columns=['TP'], 
                               data=list(matchups_win_stats.values()))
    week_res_df = pd.DataFrame(index=exp_result.keys(), columns=['ER'], 
                               data=list(exp_result.values()))
    add = get_places_table(vvv, cat)
    
    vvv = vvv.merge(score_df, how='outer', left_index=True, right_index=True)
    if league in cat_subset:
        vvv = vvv.merge(exp_score_df, how='outer', left_index=True, right_index=True)
    else:
        vvv = vvv.merge(matchups_df, how='outer', left_index=True, right_index=True)
        vvv = vvv.merge(week_res_df, how='outer', left_index=True, right_index=True)
    addded = vvv.merge(add, how='outer', left_index=True, right_index=True)
    addded = addded.sort_values(['SUM', 'PTS'])
    
    additional_cols = ['Score', 'TP', 'ER']
    if league in cat_subset:
        additional_cols = ['Score', 'ExpScore']
    to_add = pd.DataFrame(data=list(get_best_and_worst_rows(addded, cat + additional_cols)), 
                          index=['Best', 'Worst'])
    aaa = addded.append(to_add, sort=False)
    styles = [dict(selector='caption', props=[('text-align', 'center')])]
    aaa_styler = aaa.style.set_table_styles(styles).\
        apply(color_category_column, subset=pd.IndexSlice[aaa.index, set(additional_cols + cat) - {'ER'}]).\
        set_caption(f'{league_name}, week {week}').\
        apply(color_place_column, subset=pd.IndexSlice[addded.index, [f'{c} ' for c in cat]])
    if league not in cat_subset:
        aaa_styler = aaa_styler.applymap(color_matchup_result, subset=pd.IndexSlice[addded.index, ['ER']])
    display(aaa_styler)
# Out:
# <style  type="text/css" >
#     #T_50735ec8_2194_11ea_b51c_f218983e2b56 caption {
#           text-align: center;
#     }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row0_col0 {
#             background-color:  lightgreen;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row0_col9 {
#             background-color:  lightgreen;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row0_col10 {
#             background-color:  lightgreen;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row0_col11 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row0_col12 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row0_col13 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row0_col14 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row0_col15 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row0_col16 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row0_col17 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row0_col18 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row0_col19 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row1_col2 {
#             background-color:  lightgreen;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row1_col8 {
#             background-color:  lightgreen;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row1_col11 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row1_col12 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row1_col13 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row1_col14 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row1_col15 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row1_col16 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row1_col17 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row1_col18 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row1_col19 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row2_col3 {
#             background-color:  lightgreen;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row2_col4 {
#             background-color:  lightgreen;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row2_col7 {
#             background-color:  orange;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row2_col11 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row2_col12 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row2_col13 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row2_col14 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row2_col15 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row2_col16 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row2_col17 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row2_col18 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row2_col19 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row3_col5 {
#             background-color:  lightgreen;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row3_col11 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row3_col12 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row3_col13 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row3_col14 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row3_col15 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row3_col16 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row3_col17 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row3_col18 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row3_col19 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row4_col11 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row4_col12 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row4_col13 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row4_col14 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row4_col15 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row4_col16 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row4_col17 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row4_col18 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row4_col19 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row5_col6 {
#             background-color:  lightgreen;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row5_col11 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row5_col12 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row5_col13 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row5_col14 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row5_col15 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row5_col16 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row5_col17 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row5_col18 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row5_col19 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row6_col1 {
#             background-color:  lightgreen;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row6_col4 {
#             background-color:  orange;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row6_col11 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row6_col12 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row6_col13 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row6_col14 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row6_col15 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row6_col16 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row6_col17 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row6_col18 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row6_col19 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row7_col11 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row7_col12 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row7_col13 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row7_col14 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row7_col15 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row7_col16 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row7_col17 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row7_col18 {
#             color:  red;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row7_col19 {
#             color:  blue;
#         }    #T_50735ec8_2194_11ea_b51c_f218983e2b56row8_col1 {
#             background-color:  orange;
# <style  type="text/css" >
#     #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56 caption {
#           text-align: center;
#     }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row0_col7 {
#             background-color:  orange;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row0_col9 {
#             background-color:  lightgreen;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row0_col10 {
#             background-color:  lightgreen;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row0_col11 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row0_col12 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row0_col13 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row0_col14 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row0_col15 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row0_col16 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row0_col17 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row0_col18 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row0_col19 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row1_col5 {
#             background-color:  lightgreen;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row1_col11 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row1_col12 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row1_col13 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row1_col14 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row1_col15 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row1_col16 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row1_col17 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row1_col18 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row1_col19 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row2_col2 {
#             background-color:  lightgreen;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row2_col4 {
#             background-color:  lightgreen;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row2_col11 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row2_col12 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row2_col13 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row2_col14 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row2_col15 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row2_col16 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row2_col17 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row2_col18 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row2_col19 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row3_col2 {
#             background-color:  lightgreen;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row3_col8 {
#             background-color:  lightgreen;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row3_col11 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row3_col12 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row3_col13 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row3_col14 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row3_col15 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row3_col16 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row3_col17 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row3_col18 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row3_col19 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row4_col1 {
#             background-color:  orange;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row4_col3 {
#             background-color:  lightgreen;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row4_col11 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row4_col12 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row4_col13 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row4_col14 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row4_col15 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row4_col16 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row4_col17 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row4_col18 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row4_col19 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row5_col1 {
#             background-color:  lightgreen;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row5_col11 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row5_col12 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row5_col13 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row5_col14 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row5_col15 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row5_col16 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row5_col17 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row5_col18 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row5_col19 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row6_col2 {
#             background-color:  lightgreen;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row6_col11 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row6_col12 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row6_col13 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row6_col14 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row6_col15 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row6_col16 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row6_col17 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row6_col18 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row6_col19 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row7_col0 {
#             background-color:  orange;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row7_col5 {
#             background-color:  lightgreen;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row7_col11 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row7_col12 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row7_col13 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row7_col14 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row7_col15 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row7_col16 {
#             color:  blue;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row7_col17 {
#             color:  red;
#         }    #T_57d0c6ba_2194_11ea_b8b8_f218983e2b56row7_col18 {
# <style  type="text/css" >
#     #T_5f20c064_2194_11ea_8c71_f218983e2b56 caption {
#           text-align: center;
#     }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row0_col6 {
#             background-color:  lightgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row0_col7 {
#             background-color:  lightgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row0_col9 {
#             background-color:  lightgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row0_col10 {
#             color:  darkgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row0_col11 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row0_col12 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row0_col13 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row0_col14 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row0_col15 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row0_col16 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row0_col17 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row0_col18 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row1_col3 {
#             background-color:  lightgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row1_col10 {
#             color:  darkgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row1_col11 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row1_col12 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row1_col13 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row1_col14 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row1_col15 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row1_col16 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row1_col17 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row1_col18 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row2_col4 {
#             background-color:  lightgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row2_col10 {
#             color:  darkgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row2_col11 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row2_col12 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row2_col13 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row2_col14 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row2_col15 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row2_col16 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row2_col17 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row2_col18 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row3_col10 {
#             color:  darkgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row3_col11 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row3_col12 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row3_col13 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row3_col14 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row3_col15 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row3_col16 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row3_col17 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row3_col18 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row4_col1 {
#             background-color:  orange;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row4_col2 {
#             background-color:  lightgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row4_col10 {
#             color:  darkred;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row4_col11 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row4_col12 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row4_col13 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row4_col14 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row4_col15 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row4_col16 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row4_col17 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row4_col18 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row5_col10 {
#             color:  darkgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row5_col11 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row5_col12 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row5_col13 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row5_col14 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row5_col15 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row5_col16 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row5_col17 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row5_col18 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row6_col10 {
#             color:  darkred;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row6_col11 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row6_col12 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row6_col13 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row6_col14 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row6_col15 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row6_col16 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row6_col17 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row6_col18 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row7_col10 {
#             color:  darkgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row7_col11 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row7_col12 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row7_col13 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row7_col14 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row7_col15 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row7_col16 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row7_col17 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row7_col18 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row8_col5 {
#             background-color:  lightgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row8_col10 {
#             color:  darkgreen;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row8_col11 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row8_col12 {
#             color:  blue;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row8_col13 {
#             color:  red;
#         }    #T_5f20c064_2194_11ea_8c71_f218983e2b56row8_col14 {
#             color:  red;
#         }    #T_5f20c
# <style  type="text/css" >
#     #T_666d1c46_2194_11ea_afa7_f218983e2b56 caption {
#           text-align: center;
#     }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row0_col3 {
#             background-color:  lightgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row0_col4 {
#             background-color:  lightgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row0_col9 {
#             background-color:  lightgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row0_col10 {
#             color:  darkgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row0_col11 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row0_col12 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row0_col13 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row0_col14 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row0_col15 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row0_col16 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row0_col17 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row0_col18 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row1_col0 {
#             background-color:  lightgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row1_col7 {
#             background-color:  lightgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row1_col8 {
#             background-color:  lightgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row1_col10 {
#             color:  darkgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row1_col11 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row1_col12 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row1_col13 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row1_col14 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row1_col15 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row1_col16 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row1_col17 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row1_col18 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row2_col10 {
#             color:  darkgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row2_col11 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row2_col12 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row2_col13 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row2_col14 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row2_col15 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row2_col16 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row2_col17 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row2_col18 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row3_col5 {
#             background-color:  lightgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row3_col10 {
#             color:  darkgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row3_col11 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row3_col12 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row3_col13 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row3_col14 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row3_col15 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row3_col16 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row3_col17 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row3_col18 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row4_col10 {
#             color:  darkgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row4_col11 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row4_col12 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row4_col13 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row4_col14 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row4_col15 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row4_col16 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row4_col17 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row4_col18 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row5_col2 {
#             background-color:  lightgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row5_col10 {
#             color:  darkgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row5_col11 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row5_col12 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row5_col13 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row5_col14 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row5_col15 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row5_col16 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row5_col17 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row5_col18 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row6_col1 {
#             background-color:  orange;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row6_col10 {
#             color:  darkgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row6_col11 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row6_col12 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row6_col13 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row6_col14 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row6_col15 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row6_col16 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row6_col17 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row6_col18 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row7_col6 {
#             background-color:  lightgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row7_col10 {
#             color:  darkred;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row7_col11 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row7_col12 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row7_col13 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row7_col14 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row7_col15 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row7_col16 {
#             color:  red;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row7_col17 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row7_col18 {
#             color:  blue;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row8_col1 {
#             background-color:  lightgreen;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row8_col10 {
#             color:  darkred;
#         }    #T_666d1c46_2194_11ea_afa7_f218983e2b56row
# <style  type="text/css" >
#     #T_6d92ed02_2194_11ea_9e67_f218983e2b56 caption {
#           text-align: center;
#     }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row0_col0 {
#             background-color:  lightgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row0_col3 {
#             background-color:  lightgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row0_col9 {
#             background-color:  lightgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row0_col10 {
#             color:  darkgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row0_col11 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row0_col12 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row0_col13 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row0_col14 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row0_col15 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row0_col16 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row0_col17 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row0_col18 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row1_col2 {
#             background-color:  lightgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row1_col10 {
#             color:  darkgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row1_col11 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row1_col12 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row1_col13 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row1_col14 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row1_col15 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row1_col16 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row1_col17 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row1_col18 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row2_col5 {
#             background-color:  lightgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row2_col8 {
#             background-color:  lightgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row2_col10 {
#             color:  darkgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row2_col11 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row2_col12 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row2_col13 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row2_col14 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row2_col15 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row2_col16 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row2_col17 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row2_col18 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row3_col7 {
#             background-color:  lightgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row3_col10 {
#             color:  darkgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row3_col11 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row3_col12 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row3_col13 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row3_col14 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row3_col15 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row3_col16 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row3_col17 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row3_col18 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row4_col6 {
#             background-color:  lightgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row4_col10 {
#             color:  darkgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row4_col11 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row4_col12 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row4_col13 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row4_col14 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row4_col15 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row4_col16 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row4_col17 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row4_col18 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row5_col10 {
#             color:  darkgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row5_col11 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row5_col12 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row5_col13 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row5_col14 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row5_col15 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row5_col16 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row5_col17 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row5_col18 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row6_col10 {
#             color:  darkred;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row6_col11 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row6_col12 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row6_col13 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row6_col14 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row6_col15 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row6_col16 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row6_col17 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row6_col18 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row7_col10 {
#             color:  darkred;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row7_col11 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row7_col12 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row7_col13 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row7_col14 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row7_col15 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row7_col16 {
#             color:  red;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row7_col17 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row7_col18 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row8_col10 {
#             color:  darkgreen;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row8_col11 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row8_col12 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row8_col13 {
#             color:  blue;
#         }    #T_6d92ed02_2194_11ea_9e67_f218983e2b56row8_col14 {
#             color:  red;
#         }    #T_6
# <style  type="text/css" >
#     #T_7499b2e8_2194_11ea_9da2_f218983e2b56 caption {
#           text-align: center;
#     }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row0_col6 {
#             background-color:  lightgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row0_col8 {
#             background-color:  lightgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row0_col10 {
#             color:  darkgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row0_col11 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row0_col12 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row0_col13 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row0_col14 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row0_col15 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row0_col16 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row0_col17 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row0_col18 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row1_col9 {
#             background-color:  lightgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row1_col10 {
#             color:  darkgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row1_col11 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row1_col12 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row1_col13 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row1_col14 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row1_col15 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row1_col16 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row1_col17 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row1_col18 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row2_col0 {
#             background-color:  lightgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row2_col10 {
#             color:  darkgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row2_col11 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row2_col12 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row2_col13 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row2_col14 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row2_col15 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row2_col16 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row2_col17 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row2_col18 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row3_col5 {
#             background-color:  lightgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row3_col10 {
#             color:  darkgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row3_col11 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row3_col12 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row3_col13 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row3_col14 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row3_col15 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row3_col16 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row3_col17 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row3_col18 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row4_col2 {
#             background-color:  lightgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row4_col10 {
#             color:  darkred;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row4_col11 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row4_col12 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row4_col13 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row4_col14 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row4_col15 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row4_col16 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row4_col17 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row4_col18 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row5_col6 {
#             background-color:  lightgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row5_col10 {
#             color:  darkgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row5_col11 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row5_col12 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row5_col13 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row5_col14 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row5_col15 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row5_col16 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row5_col17 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row5_col18 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row6_col6 {
#             background-color:  lightgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row6_col10 {
#             color:  darkgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row6_col11 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row6_col12 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row6_col13 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row6_col14 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row6_col15 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row6_col16 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row6_col17 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row6_col18 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row7_col10 {
#             color:  darkgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row7_col11 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row7_col12 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row7_col13 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row7_col14 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row7_col15 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row7_col16 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row7_col17 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row7_col18 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row8_col1 {
#             background-color:  lightgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row8_col10 {
#             color:  darkgreen;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row8_col11 {
#             color:  red;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row8_col12 {
#             color:  blue;
#         }    #T_7499b2e8_2194_11ea_9da2_f218983e2b56row8_col13 {
#             color:  red;
# <style  type="text/css" >
#     #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56 caption {
#           text-align: center;
#     }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row0_col2 {
#             background-color:  lightgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row0_col7 {
#             background-color:  lightgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row0_col9 {
#             background-color:  lightgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row0_col10 {
#             color:  darkgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row0_col11 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row0_col12 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row0_col13 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row0_col14 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row0_col15 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row0_col16 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row0_col17 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row0_col18 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row1_col10 {
#             color:  darkgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row1_col11 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row1_col12 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row1_col13 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row1_col14 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row1_col15 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row1_col16 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row1_col17 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row1_col18 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row2_col5 {
#             background-color:  lightgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row2_col10 {
#             color:  darkgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row2_col11 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row2_col12 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row2_col13 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row2_col14 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row2_col15 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row2_col16 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row2_col17 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row2_col18 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row3_col3 {
#             background-color:  lightgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row3_col4 {
#             background-color:  lightgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row3_col10 {
#             color:  darkgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row3_col11 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row3_col12 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row3_col13 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row3_col14 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row3_col15 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row3_col16 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row3_col17 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row3_col18 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row4_col10 {
#             color:  darkgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row4_col11 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row4_col12 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row4_col13 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row4_col14 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row4_col15 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row4_col16 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row4_col17 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row4_col18 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row5_col10 {
#             color:  darkred;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row5_col11 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row5_col12 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row5_col13 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row5_col14 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row5_col15 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row5_col16 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row5_col17 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row5_col18 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row6_col8 {
#             background-color:  lightgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row6_col10 {
#             color:  darkgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row6_col11 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row6_col12 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row6_col13 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row6_col14 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row6_col15 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row6_col16 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row6_col17 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row6_col18 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row7_col10 {
#             color:  darkgreen;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row7_col11 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row7_col12 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row7_col13 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row7_col14 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row7_col15 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row7_col16 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row7_col17 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row7_col18 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row8_col10 {
#             color:  darkred;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row8_col11 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row8_col12 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row8_col13 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row8_col14 {
#             color:  blue;
#         }    #T_7ba03ae4_2194_11ea_b0a1_f218983e2b56row8_col15 {
#             color:  red;
#         }    #T_7ba03ae4_2194_11e

# %%
cat_limit = 7
win_limit = 9
total_limit = 9
n_weeks = 9
leagues = [43767928, 134112, 99121987, 282844, 199973, 142634, 174837]
cat_susbet = [43767928, 134112]
# leagues = [43767928]
browser = webdriver.Chrome()
for league in leagues:
    espn_scoreboard_url = 'https://fantasy.espn.com/basketball/league/scoreboard'
    links = [f'{espn_scoreboard_url}?leagueId={league}&matchupPeriodId={week+1}' for week in range(n_weeks)]
    
    all_scores = defaultdict(list)
    all_matchup_results = defaultdict(list)
    all_exp_scores = defaultdict(list)
    all_matchup_exp_results = defaultdict(list)
    all_matchups_won = defaultdict(list)
    
    for link in links:
        browser.get(link)
        time.sleep(10)
        scoreboard_html_source = BeautifulSoup(browser.page_source)
        league_name = get_league_name(scoreboard_html_source)

        res, cat = get_week_results(scoreboard_html_source)

        week_scores = get_scores_info(res, cat)
        for team in week_scores:
            week_wins = Counter()
            for opp in week_scores:
                if opp == team:
                    continue
                fake_matchup_res = get_matchup_result(week_scores[team], week_scores[opp], cat)
                week_wins[fake_matchup_res] += 1
            all_matchups_won[team].append('-'.join(map(str, [week_wins['W'], week_wins['L'], week_wins['D']])))
            
        scores = get_week_stats(scoreboard_html_source, 'NBA')
        scores_dict = {}
        
        opp_dict = {}
        for sc in scores:
            scores_dict.update(sc)
            opp_dict[sc[0][0]] = sc[1][0]
            opp_dict[sc[1][0]] = sc[0][0]
            
        for team in opp_dict:
            team_sc = np.array(scores_dict[team].split('-'))
            opp_sc = np.array(scores_dict[opp_dict[team]].split('-'))
            if compare_scores(team_sc, opp_sc):
                all_matchup_results[team].append('W')
            elif compare_scores(opp_sc, team_sc):
                all_matchup_results[team].append('L')
            else:
                all_matchup_results[team].append('D')
        
        for team in scores_dict:
            all_scores[team].append(scores_dict[team])

        exp_score, exp_result = get_expected_score_and_result(res)
        for team in exp_score:
            all_exp_scores[team].append(exp_score[team])
            all_matchup_exp_results[team].append(exp_result[team])

    for team in all_scores:
        stats = [np.array(list(map(float, score.split('-')))) for score in all_scores[team]]
        stats_array = np.vstack(stats)
        res = stats_array.sum(axis=0)
        all_scores[team].append('-'.join(list(map(lambda x: str(x) if x % 1.0 > 1e-7 else str(int(x)), res))))
        
    for team in all_exp_scores:
        stats = [np.array(list(map(float, score.split('-')))) for score in all_exp_scores[team]]
        stats_array = np.vstack(stats)
        res = list(map(lambda x: np.round(x, 1), stats_array.sum(axis=0)))
        all_exp_scores[team].append('-'.join(map(lambda x: str(x) if x % 1.0 > 1e-7 else str(int(x)), res)))
        
    for team in all_matchup_results:
        all_matchup_results[team].append(calc_team_win_stat(all_matchup_results[team]))
        
    for team in all_matchup_exp_results:
        all_matchup_exp_results[team].append(calc_team_win_stat(all_matchup_exp_results[team]))
    
    for team in all_matchups_won:
        stats = [np.array(list(map(float, score.split('-')))) for score in all_matchups_won[team]]
        stats_array = np.vstack(stats)
        res = list(map(lambda x: np.round(x, 1), stats_array.sum(axis=0)))
        all_matchups_won[team].append('-'.join(map(lambda x: str(x) if x % 1.0 > 1e-7 else str(int(x)), res)))
    
    table_data_dict = {team : all_exp_scores[team][len(all_exp_scores[team])-1-cat_limit:] for team in all_exp_scores}
    for team in table_data_dict:
        table_data_dict[team].append(all_scores[team][-1])
        table_data_dict[team].extend(get_diff(table_data_dict[team][-1], table_data_dict[team][-2]))
        
    table_win_data_dict = {team : all_matchup_exp_results[team][len(all_matchup_exp_results[team])-1-win_limit:] for team in all_matchup_exp_results}
    for team in table_win_data_dict:
        table_win_data_dict[team].append(all_matchup_results[team][-1])
        table_win_data_dict[team].extend(get_diff(table_win_data_dict[team][-1], table_win_data_dict[team][-2]))
    
    matchups_data_dict = {team: all_matchups_won[team][len(all_matchups_won[team]) - 1 - total_limit:] for team in all_matchups_won}
    for team in matchups_data_dict:
        matchups_data_dict[team].extend(map(int, matchups_data_dict[team].pop().split('-')))
    
    
    df_matchups = pd.DataFrame(data=list(matchups_data_dict.values()), 
                               index=matchups_data_dict.keys(), 
                               columns=[f'week {i+1}' for i in range(n_weeks-total_limit, n_weeks)] + ['W', 'L', 'D'])
    df_matchups = df_matchups.sort_values(['W', 'D'], ascending=False)
    to_add = pd.DataFrame(data=list(get_best_and_worst_rows_for_scores(df_matchups)), 
                          index=['Best', 'Worst'])
    df_matchups = df_matchups.append(to_add, sort=False)
    styles = [dict(selector='caption', props=[('text-align', 'center')])]
    df_matchups_styler = df_matchups.style.set_table_styles(styles).\
        set_caption(f'{league_name}').\
        apply(color_category_column, subset=[f'week {i+1}' for i in range(n_weeks-total_limit, n_weeks)])
    display(df_matchups_styler)
    
    if league not in cat_subset:
        df_win = pd.DataFrame(data=list(table_win_data_dict.values()), 
                              index=table_win_data_dict.keys(), 
                              columns=[f'week {i+1}' for i in range(n_weeks-win_limit, n_weeks)] + ['Total', 'ESPN', 'WD', 'LD', 'DD'])
        df_win = df_win.sort_values(['WD', 'DD'], ascending=False)
        styles = [dict(selector='caption', props=[('text-align', 'center')])]
        df_win_styler = df_win.style.set_table_styles(styles).\
            set_caption(f'{league_name}').\
            applymap(color_matchup_res, subset=[f'week {i+1}' for i in range(n_weeks-win_limit, n_weeks)]).\
            applymap(color_value, subset=pd.IndexSlice[table_data_dict.keys(), ['WD']])
        display(df_win_styler)
        
    if league in cat_subset:
        df = pd.DataFrame(data=list(table_data_dict.values()), 
                          index=table_data_dict.keys(), 
                          columns=[f'week {i+1}' for i in range(n_weeks-cat_limit, n_weeks)] + ['Total', 'ESPN', 'WD', 'LD', 'DD'])
        df = df.sort_values(['WD', 'DD'], ascending=False)
        to_add = pd.DataFrame(data=list(get_best_and_worst_rows_for_scores(df)), 
                              index=['Best', 'Worst'])
        df = df.append(to_add, sort=False)
        styles = [dict(selector='caption', props=[('text-align', 'center')])]
        df_styler = df.style.set_table_styles(styles).\
            set_caption(f'{league_name}').\
            apply(color_category_column, subset=pd.IndexSlice[df.index, [f'week {i+1}' for i in range(n_weeks-cat_limit, n_weeks)] + ['Total', 'ESPN']]).\
            applymap(color_value, subset=pd.IndexSlice[table_data_dict.keys(), ['WD']])
        display(df_styler)
